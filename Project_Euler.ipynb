# %% [markdown]
# Problem 1: Find sum of all the multiples of 3 or 5 below 1000

# %%
def problem_1(n = 1000):
    result = 0
    for i in range(n):
        if i%3 ==0 or i%5 == 0:
            result+=i
    return result

# %%
problem_1()
# Out:
# 233168

# %% [markdown]
# Problem 2: Find the sum of the even-valued terms in the fibb sequence

# %%
def problem_2():
    n1 = 0
    n2 = 1
    result = 0
    fib_seq = []
    fib_seq.append(n1)
    fib_seq.append(n2)
    nth = 0
    while nth < 4000001:
        nth = n1 + n2
        # update values
        n1 = n2
        n2 = nth
        fib_seq.append(nth)
    for i in fib_seq:
        if i %2 ==0:
            result+=i
    return result

# %%
print(problem_2())
# Out:
# 4613732

# %% [markdown]
# Problem 3: What is the largest prime factor of the number 600851475143 ?
